# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 790

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]        
       # city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        city_weather_description = city_weather["weather"][0]["description"]
        
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description})
                          #"Date": city_date})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | roald
# Processing Record 2 of Set 1 | torbay
# Processing Record 3 of Set 1 | ilulissat
# Processing Record 4 of Set 1 | bluff
# Processing Record 5 of Set 1 | stoyba
# City not found. Skipping...
# Processing Record 6 of Set 1 | candido de abreu
# Processing Record 7 of Set 1 | mar del plata
# Processing Record 8 of Set 1 | atuona
# Processing Record 9 of Set 1 | vaini
# Processing Record 10 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 11 of Set 1 | presque isle
# Processing Record 12 of Set 1 | bengkulu
# Processing Record 13 of Set 1 | mataura
# Processing Record 14 of Set 1 | mersing
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | pevek
# Processing Record 17 of Set 1 | avarua
# Processing Record 18 of Set 1 | ratnagiri
# Processing Record 19 of Set 1 | araouane
# Processing Record 20 of Set 1 | nenjiang
# Processing Record 21 of Set 1 | leningradskiy
# Processing Record 22 of Set 1 | pierre
# Processing Record 23 of Set 1 | san quintin
# Processing Record 24 of Set 1 | jamestown
# Processing Record 25 of Set 1 | gouloure
# Processing Record 26 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 27 of Set 1 | pisco
# Processing Record 28 of Set 1 | kruisfontein
# Processing Record 29 of Set 1 | georgetown
# Processing Record 30 of Set 1 | saint-joseph
# Processing Record 31 of Set 1 | caucaia
# Processing Record 32 of Set 1 | severo-kurilsk
# Processing Record 33 of Set 1 | gravdal
# Processing Record 34 of Set 1 | hilo
# Processing Record 35 of Set 1 | san patricio
# Processing Record 36 of Set 1 | kahului
# Processing Record 37 of Set 1 | puerto ayora
# Processing Record 38 of Set 1 | tabiauea
# City not found. Skipping...
# Processing Record 39 of Set 1 | barrow
# Processing Record 40 of Set 1 | tuatapere
# Processing Record 41 of Set 1 | codrington
# Processing Record 42 of Set 1 | punta arenas
# Processing Record 43 of Set 1 | nikolskoye
# Processing Record 44 of Set 1 | qaanaaq
# Processing Record 45 of Set 1 | nabire
# Processing Record 46 of Set 1 | carauari
# Processing Record 47 of Set 1 | henties bay
# Processing Record 48 of Set 1 | shirwal
# Processing Record 49 of Set 1 | fortuna
# Processing Record 50 of Set 1 | marsa matruh
# Processing Record 1 of Set 2 | kodiak
# Processing Record 2 of Set 2 | kapaa
# Processing Record 3 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 2 | hobart
# Processing Record 5 of Set 2 | parabel
# Processing Record 6 of Set 2 | dolbeau
# City not found. Skipping...
# Processing Record 7 of Set 2 | kargil
# Processing Record 8 of Set 2 | ouango
# Processing Record 9 of Set 2 | port alfred
# Processing Record 10 of Set 2 | cherskiy
# Processing Record 11 of Set 2 | songjianghe
# Processing Record 12 of Set 2 | reitz
# Processing Record 13 of Set 2 | victoria
# Processing Record 14 of Set 2 | hervey bay
# Processing Record 15 of Set 2 | carnarvon
# Processing Record 16 of Set 2 | upernavik
# Processing Record 17 of Set 2 | baruun-urt
# Processing Record 18 of Set 2 | butaritari
# Processing Record 19 of Set 2 | cidreira
# Processing Record 20 of Set 2 | saint-philippe
# Processing Record 21 of Set 2 | biak
# Processing Record 22 of Set 2 | cizre
# Processing Record 23 of Set 2 | saint george
# Processing Record 24 of Set 2 | inongo
# Processing Record 25 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 26 of Set 2 | todos santos
# Processing Record 27 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 28 of Set 2 | ushuaia
# Processing Record 29 of Set 2 | hermanus
# Processing Record 30 of Set 2 | klaksvik
# Processing Record 31 of Set 2 | kapoeta
# Processing Record 32 of Set 2 | biloela
# Processing Record 33 of Set 2 | port hardy
# Processing Record 34 of Set 2 | manggar
# Processing Record 35 of Set 2 | verkh-usugli
# Processing Record 36 of Set 2 | esperance
# Processing Record 37 of Set 2 | bathsheba
# Processing Record 38 of Set 2 | chokurdakh
# Processing Record 39 of Set 2 | sao joao do paraiso
# Processing Record 40 of Set 2 | zakamensk
# Processing Record 41 of Set 2 | albany
# Processing Record 42 of Set 2 | salalah
# Processing Record 43 of Set 2 | cabo san lucas
# Processing Record 44 of Set 2 | bredasdorp
# Processing Record 45 of Set 2 | cape town
# Processing Record 46 of Set 2 | dolny kubin
# Processing Record 47 of Set 2 | zhuanghe
# Processing Record 48 of Set 2 | beidao
# Processing Record 49 of Set 2 | port elizabeth
# Processing Record 50 of Set 2 | sedhiou
# Processing Record 1 of Set 3 | thompson
# Processing Record 2 of Set 3 | tecoanapa
# Processing Record 3 of Set 3 | kuzhenkino
# Processing Record 4 of Set 3 | tucupita
# Processing Record 5 of Set 3 | orlik
# Processing Record 6 of Set 3 | oussouye
# Processing Record 7 of Set 3 | mahebourg
# Processing Record 8 of Set 3 | mindelo
# Processing Record 9 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 10 of Set 3 | paamiut
# Processing Record 11 of Set 3 | maues
# Processing Record 12 of Set 3 | wanning
# Processing Record 13 of Set 3 | saskylakh
# Processing Record 14 of Set 3 | sao filipe
# Processing Record 15 of Set 3 | yellowknife
# Processing Record 16 of Set 3 | fossano
# Processing Record 17 of Set 3 | new norfolk
# Processing Record 18 of Set 3 | dukat
# Processing Record 19 of Set 3 | okahandja
# Processing Record 20 of Set 3 | itaituba
# Processing Record 21 of Set 3 | east london
# Processing Record 22 of Set 3 | lodwar
# Processing Record 23 of Set 3 | san andres
# Processing Record 24 of Set 3 | zachary
# Processing Record 25 of Set 3 | hualmay
# Processing Record 26 of Set 3 | puerto del rosario
# Processing Record 27 of Set 3 | lavrentiya
# Processing Record 28 of Set 3 | snezhnogorsk
# Processing Record 29 of Set 3 | ingham
# Processing Record 30 of Set 3 | poum
# Processing Record 31 of Set 3 | mackay
# Processing Record 32 of Set 3 | castro
# Processing Record 33 of Set 3 | korem
# Processing Record 34 of Set 3 | busselton
# Processing Record 35 of Set 3 | ponta do sol
# Processing Record 36 of Set 3 | faanui
# Processing Record 37 of Set 3 | yarada
# Processing Record 38 of Set 3 | cayenne
# Processing Record 39 of Set 3 | ribeira grande
# Processing Record 40 of Set 3 | yinchuan
# Processing Record 41 of Set 3 | shimoda
# Processing Record 42 of Set 3 | nanortalik
# Processing Record 43 of Set 3 | leh
# Processing Record 44 of Set 3 | hofn
# Processing Record 45 of Set 3 | golfito
# Processing Record 46 of Set 3 | chuy
# Processing Record 47 of Set 3 | kargat
# Processing Record 48 of Set 3 | mwinilunga
# Processing Record 49 of Set 3 | lagoa
# Processing Record 50 of Set 3 | sauk rapids
# Processing Record 1 of Set 4 | srednekolymsk
# Processing Record 2 of Set 4 | shitanjing
# Processing Record 3 of Set 4 | sinnamary
# Processing Record 4 of Set 4 | bilma
# Processing Record 5 of Set 4 | basco
# Processing Record 6 of Set 4 | yaan
# Processing Record 7 of Set 4 | hurghada
# Processing Record 8 of Set 4 | bristol
# Processing Record 9 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 10 of Set 4 | taos
# Processing Record 11 of Set 4 | doka
# Processing Record 12 of Set 4 | muisne
# Processing Record 13 of Set 4 | lakes entrance
# Processing Record 14 of Set 4 | dakar
# Processing Record 15 of Set 4 | hovd
# Processing Record 16 of Set 4 | valleyview
# Processing Record 17 of Set 4 | dikson
# Processing Record 18 of Set 4 | mayya
# Processing Record 19 of Set 4 | santa isabel
# Processing Record 20 of Set 4 | katsuura
# Processing Record 21 of Set 4 | uvinza
# Processing Record 22 of Set 4 | hami
# Processing Record 23 of Set 4 | hamilton
# Processing Record 24 of Set 4 | norman wells
# Processing Record 25 of Set 4 | anadyr
# Processing Record 26 of Set 4 | nouakchott
# Processing Record 27 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 28 of Set 4 | rawson
# Processing Record 29 of Set 4 | kavaratti
# Processing Record 30 of Set 4 | iqaluit
# Processing Record 31 of Set 4 | thunder bay
# Processing Record 32 of Set 4 | denpasar
# Processing Record 33 of Set 4 | ormara
# Processing Record 34 of Set 4 | houston
# Processing Record 35 of Set 4 | dawlatabad
# Processing Record 36 of Set 4 | udachnyy
# Processing Record 37 of Set 4 | zwedru
# Processing Record 38 of Set 4 | caravelas
# Processing Record 39 of Set 4 | kitakata
# Processing Record 40 of Set 4 | kaspiysk
# Processing Record 41 of Set 4 | tilichiki
# Processing Record 42 of Set 4 | mahanje
# Processing Record 43 of Set 4 | kaitangata
# Processing Record 44 of Set 4 | port blair
# Processing Record 45 of Set 4 | klyuchi
# Processing Record 46 of Set 4 | oga
# Processing Record 47 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 48 of Set 4 | teya
# Processing Record 49 of Set 4 | port hedland
# Processing Record 50 of Set 4 | tuktoyaktuk
# Processing Record 1 of Set 5 | touros
# Processing Record 2 of Set 5 | samalaeulu
# City not found. Skipping...
# Processing Record 3 of Set 5 | moose factory
# Processing Record 4 of Set 5 | pochutla
# Processing Record 5 of Set 5 | agar
# Processing Record 6 of Set 5 | hohhot
# Processing Record 7 of Set 5 | athol
# Processing Record 8 of Set 5 | namatanai
# Processing Record 9 of Set 5 | makakilo city
# Processing Record 10 of Set 5 | carutapera
# Processing Record 11 of Set 5 | vestmannaeyjar
# Processing Record 12 of Set 5 | luderitz
# Processing Record 13 of Set 5 | tual
# Processing Record 14 of Set 5 | graneros
# Processing Record 15 of Set 5 | yanan
# City not found. Skipping...
# Processing Record 16 of Set 5 | bonthe
# Processing Record 17 of Set 5 | port lincoln
# Processing Record 18 of Set 5 | los rastrojos
# Processing Record 19 of Set 5 | aras
# Processing Record 20 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of Set 5 | coihaique
# Processing Record 22 of Set 5 | zhezkazgan
# Processing Record 23 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 24 of Set 5 | pangnirtung
# Processing Record 25 of Set 5 | agadez
# Processing Record 26 of Set 5 | arraial do cabo
# Processing Record 27 of Set 5 | mangrol
# Processing Record 28 of Set 5 | berlevag
# Processing Record 29 of Set 5 | notse
# Processing Record 30 of Set 5 | kaduna
# Processing Record 31 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 32 of Set 5 | acarau
# Processing Record 33 of Set 5 | coquimbo
# Processing Record 34 of Set 5 | tasiilaq
# Processing Record 35 of Set 5 | mae hong son
# Processing Record 36 of Set 5 | vostok
# Processing Record 37 of Set 5 | faya
# Processing Record 38 of Set 5 | provideniya
# Processing Record 39 of Set 5 | livramento
# Processing Record 40 of Set 5 | turochak
# Processing Record 41 of Set 5 | narsaq
# Processing Record 42 of Set 5 | soyo
# Processing Record 43 of Set 5 | deputatskiy
# Processing Record 44 of Set 5 | lyubech
# Processing Record 45 of Set 5 | aklavik
# Processing Record 46 of Set 5 | jieshi
# Processing Record 47 of Set 5 | marienburg
# Processing Record 48 of Set 5 | belaya gora
# Processing Record 49 of Set 5 | madang
# Processing Record 50 of Set 5 | maloshuyka
# City not found. Skipping...
# Processing Record 1 of Set 6 | komsomolskiy
# Processing Record 2 of Set 6 | pampa
# Processing Record 3 of Set 6 | talara
# Processing Record 4 of Set 6 | nouadhibou
# Processing Record 5 of Set 6 | khatanga
# Processing Record 6 of Set 6 | camopi
# Processing Record 7 of Set 6 | singarayakonda
# Processing Record 8 of Set 6 | tiksi
# Processing Record 9 of Set 6 | igrim
# Processing Record 10 of Set 6 | new smyrna beach
# Processing Record 11 of Set 6 | del rio
# Processing Record 12 of Set 6 | eydhafushi
# Processing Record 13 of Set 6 | xudat
# Processing Record 14 of Set 6 | korsakov
# Processing Record 15 of Set 6 | kholbon
# Processing Record 16 of Set 6 | piacabucu
# Processing Record 17 of Set 6 | ahipara
# Processing Record 18 of Set 6 | beringovskiy
# Processing Record 19 of Set 6 | mozarlandia
# Processing Record 20 of Set 6 | belogorsk
# Processing Record 21 of Set 6 | taltal
# Processing Record 22 of Set 6 | antigonish
# Processing Record 23 of Set 6 | najran
# Processing Record 24 of Set 6 | clyde river
# Processing Record 25 of Set 6 | raga
# Processing Record 26 of Set 6 | yermakovskoye
# Processing Record 27 of Set 6 | erzin
# Processing Record 28 of Set 6 | itarema
# Processing Record 29 of Set 6 | inhambane
# Processing Record 30 of Set 6 | armash
# Processing Record 31 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 32 of Set 6 | ruatoria
# City not found. Skipping...
# Processing Record 33 of Set 6 | verkhnevilyuysk
# Processing Record 34 of Set 6 | sonoita
# Processing Record 35 of Set 6 | talnakh
# Processing Record 36 of Set 6 | taburi
# City not found. Skipping...
# Processing Record 37 of Set 6 | viedma
# Processing Record 38 of Set 6 | kavieng
# Processing Record 39 of Set 6 | longyearbyen
# Processing Record 40 of Set 6 | naze
# Processing Record 41 of Set 6 | bonavista
# Processing Record 42 of Set 6 | souillac
# Processing Record 43 of Set 6 | ivankiv
# Processing Record 44 of Set 6 | tabou
# Processing Record 45 of Set 6 | atar
# Processing Record 46 of Set 6 | balimo
# City not found. Skipping...
# Processing Record 47 of Set 6 | baijiantan
# Processing Record 48 of Set 6 | aden
# Processing Record 49 of Set 6 | lompoc
# Processing Record 50 of Set 6 | mehamn
# Processing Record 1 of Set 7 | portland
# Processing Record 2 of Set 7 | flin flon
# Processing Record 3 of Set 7 | zhangjiakou
# Processing Record 4 of Set 7 | tarakan
# Processing Record 5 of Set 7 | moissala
# Processing Record 6 of Set 7 | pimentel
# Processing Record 7 of Set 7 | bubaque
# Processing Record 8 of Set 7 | christiana
# Processing Record 9 of Set 7 | tazovskiy
# Processing Record 10 of Set 7 | tornio
# Processing Record 11 of Set 7 | leninskoye
# Processing Record 12 of Set 7 | karratha
# Processing Record 13 of Set 7 | sampit
# Processing Record 14 of Set 7 | aviles
# Processing Record 15 of Set 7 | juegang
# Processing Record 16 of Set 7 | bambous virieux
# Processing Record 17 of Set 7 | ancud
# Processing Record 18 of Set 7 | gigmoto
# Processing Record 19 of Set 7 | igarka
# Processing Record 20 of Set 7 | carballo
# Processing Record 21 of Set 7 | show low
# Processing Record 22 of Set 7 | huron
# Processing Record 23 of Set 7 | mezen
# Processing Record 24 of Set 7 | fershampenuaz
# Processing Record 25 of Set 7 | ewa beach
# Processing Record 26 of Set 7 | ponta delgada
# Processing Record 27 of Set 7 | sfantu gheorghe
# Processing Record 28 of Set 7 | pyatnitskoye
# Processing Record 29 of Set 7 | grindavik
# Processing Record 30 of Set 7 | baherden
# Processing Record 31 of Set 7 | lebu
# Processing Record 32 of Set 7 | khilok
# Processing Record 33 of Set 7 | vanimo
# Processing Record 34 of Set 7 | tromso
# Processing Record 35 of Set 7 | aswan
# Processing Record 36 of Set 7 | gangtok
# Processing Record 37 of Set 7 | lorengau
# Processing Record 38 of Set 7 | dunmore town
# Processing Record 39 of Set 7 | nishihara
# Processing Record 40 of Set 7 | novoagansk
# Processing Record 41 of Set 7 | ulyanovka
# Processing Record 42 of Set 7 | mercedes
# Processing Record 43 of Set 7 | fukue
# Processing Record 44 of Set 7 | namibe
# Processing Record 45 of Set 7 | vrangel
# Processing Record 46 of Set 7 | eureka
# Processing Record 47 of Set 7 | manoel urbano
# Processing Record 48 of Set 7 | ust-ishim
# Processing Record 49 of Set 7 | vardo
# Processing Record 50 of Set 7 | acapulco
# Processing Record 1 of Set 8 | paz de ariporo
# City not found. Skipping...
# Processing Record 2 of Set 8 | san carlos de bariloche
# Processing Record 3 of Set 8 | pribelskiy
# City not found. Skipping...
# Processing Record 4 of Set 8 | aksarka
# Processing Record 5 of Set 8 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 6 of Set 8 | imeni stepana razina
# Processing Record 7 of Set 8 | korablino
# Processing Record 8 of Set 8 | abalak
# Processing Record 9 of Set 8 | novikovo
# Processing Record 10 of Set 8 | cabedelo
# Processing Record 11 of Set 8 | lafia
# Processing Record 12 of Set 8 | alta floresta
# Processing Record 13 of Set 8 | crab hill
# City not found. Skipping...
# Processing Record 14 of Set 8 | andros
# Processing Record 15 of Set 8 | roebourne
# Processing Record 16 of Set 8 | coro
# Processing Record 17 of Set 8 | mus
# Processing Record 18 of Set 8 | petapa
# Processing Record 19 of Set 8 | hithadhoo
# Processing Record 20 of Set 8 | tanggu
# Processing Record 21 of Set 8 | bardiyah
# Processing Record 22 of Set 8 | launceston
# Processing Record 23 of Set 8 | boca do acre
# Processing Record 24 of Set 8 | mayskiy
# Processing Record 25 of Set 8 | mapiri
# Processing Record 26 of Set 8 | camocim
# Processing Record 27 of Set 8 | turbiv
# Processing Record 28 of Set 8 | sembe
# Processing Record 29 of Set 8 | bembereke
# Processing Record 30 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 31 of Set 8 | banda aceh
# Processing Record 32 of Set 8 | yichang
# Processing Record 33 of Set 8 | hasaki
# Processing Record 34 of Set 8 | van
# Processing Record 35 of Set 8 | kangaatsiaq
# Processing Record 36 of Set 8 | san javier
# Processing Record 37 of Set 8 | cockburn town
# Processing Record 38 of Set 8 | shahdol
# Processing Record 39 of Set 8 | domoni
# Processing Record 40 of Set 8 | malwan
# City not found. Skipping...
# Processing Record 41 of Set 8 | manicore
# Processing Record 42 of Set 8 | fairbanks
# Processing Record 43 of Set 8 | sibiti
# Processing Record 44 of Set 8 | sloboda
# Processing Record 45 of Set 8 | roma
# Processing Record 46 of Set 8 | alyangula
# Processing Record 47 of Set 8 | margate
# Processing Record 48 of Set 8 | buqayq
# City not found. Skipping...
# Processing Record 49 of Set 8 | sao luis do quitunde
# Processing Record 50 of Set 8 | montrose
# Processing Record 1 of Set 9 | lazaro cardenas
# Processing Record 2 of Set 9 | perth
# Processing Record 3 of Set 9 | saint-augustin
# Processing Record 4 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 5 of Set 9 | ust-tsilma
# Processing Record 6 of Set 9 | olinda
# Processing Record 7 of Set 9 | vila velha
# Processing Record 8 of Set 9 | alor setar
# Processing Record 9 of Set 9 | gushikawa
# Processing Record 10 of Set 9 | murakami
# Processing Record 11 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 12 of Set 9 | alofi
# Processing Record 13 of Set 9 | yulara
# Processing Record 14 of Set 9 | dingle
# Processing Record 15 of Set 9 | oranjemund
# Processing Record 16 of Set 9 | saint-pierre
# Processing Record 17 of Set 9 | hanmer springs
# Processing Record 18 of Set 9 | miri
# Processing Record 19 of Set 9 | sur
# Processing Record 20 of Set 9 | buin
# Processing Record 21 of Set 9 | cap malheureux
# Processing Record 22 of Set 9 | barra patuca
# Processing Record 23 of Set 9 | riohacha
# Processing Record 24 of Set 9 | mount gambier
# Processing Record 25 of Set 9 | armidale
# Processing Record 26 of Set 9 | bethel
# Processing Record 27 of Set 9 | sal rei
# Processing Record 28 of Set 9 | asyut
# Processing Record 29 of Set 9 | imbituba
# Processing Record 30 of Set 9 | yumen
# Processing Record 31 of Set 9 | sinjar
# Processing Record 32 of Set 9 | saldanha
# Processing Record 33 of Set 9 | antipino
# Processing Record 34 of Set 9 | maragogi
# Processing Record 35 of Set 9 | sokolo
# Processing Record 36 of Set 9 | jiayuguan
# Processing Record 37 of Set 9 | santiago del estero
# Processing Record 38 of Set 9 | urdoma
# Processing Record 39 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 40 of Set 9 | omboue
# Processing Record 41 of Set 9 | atbasar
# Processing Record 42 of Set 9 | lamar
# Processing Record 43 of Set 9 | mayo
# Processing Record 44 of Set 9 | waynesville
# Processing Record 45 of Set 9 | broome
# Processing Record 46 of Set 9 | kunmadaras
# Processing Record 47 of Set 9 | necochea
# Processing Record 48 of Set 9 | eldikan
# City not found. Skipping...
# Processing Record 49 of Set 9 | majene
# Processing Record 50 of Set 9 | geraldton
# Processing Record 1 of Set 10 | loandjili
# Processing Record 2 of Set 10 | zalantun
# Processing Record 3 of Set 10 | ulladulla
# Processing Record 4 of Set 10 | sao paulo de olivenca
# Processing Record 5 of Set 10 | college
# Processing Record 6 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 7 of Set 10 | jinzhou
# Processing Record 8 of Set 10 | zhuhai
# Processing Record 9 of Set 10 | matay
# Processing Record 10 of Set 10 | longlac
# City not found. Skipping...
# Processing Record 11 of Set 10 | nalut
# Processing Record 12 of Set 10 | bundaberg
# Processing Record 13 of Set 10 | avera
# Processing Record 14 of Set 10 | oranjestad
# Processing Record 15 of Set 10 | derzhavinsk
# Processing Record 16 of Set 10 | broken hill
# Processing Record 17 of Set 10 | anina
# Processing Record 18 of Set 10 | fonte boa
# Processing Record 19 of Set 10 | jalu
# Processing Record 20 of Set 10 | tazmalt
# Processing Record 21 of Set 10 | bima
# Processing Record 22 of Set 10 | nelson bay
# Processing Record 23 of Set 10 | berat
# Processing Record 24 of Set 10 | don benito
# Processing Record 25 of Set 10 | togur
# Processing Record 26 of Set 10 | khuzdar
# Processing Record 27 of Set 10 | salvador
# Processing Record 28 of Set 10 | shingu
# Processing Record 29 of Set 10 | boa vista
# Processing Record 30 of Set 10 | mount isa
# Processing Record 31 of Set 10 | asau
# Processing Record 32 of Set 10 | cape canaveral
# Processing Record 33 of Set 10 | artyk
# City not found. Skipping...
# Processing Record 34 of Set 10 | vestmanna
# Processing Record 35 of Set 10 | flinders
# Processing Record 36 of Set 10 | taunggyi
# Processing Record 37 of Set 10 | mobaye
# Processing Record 38 of Set 10 | rudnogorsk
# Processing Record 39 of Set 10 | harper
# Processing Record 40 of Set 10 | saint-leu
# Processing Record 41 of Set 10 | sasebo
# Processing Record 42 of Set 10 | storforshei
# Processing Record 43 of Set 10 | coelho neto
# Processing Record 44 of Set 10 | qunduz
# Processing Record 45 of Set 10 | morehead
# Processing Record 46 of Set 10 | juli
# Processing Record 47 of Set 10 | bushehr
# Processing Record 48 of Set 10 | tamandare
# Processing Record 49 of Set 10 | manzanillo
# Processing Record 50 of Set 10 | tura
# Processing Record 1 of Set 11 | tsumeb
# Processing Record 2 of Set 11 | zhongshu
# Processing Record 3 of Set 11 | porto novo
# Processing Record 4 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 5 of Set 11 | pak phanang
# Processing Record 6 of Set 11 | kholodnyy
# Processing Record 7 of Set 11 | airai
# Processing Record 8 of Set 11 | chengam
# Processing Record 9 of Set 11 | pyaozerskiy
# Processing Record 10 of Set 11 | wichian buri
# Processing Record 11 of Set 11 | ambodifototra
# City not found. Skipping...
# Processing Record 12 of Set 11 | progreso
# Processing Record 13 of Set 11 | itoman
# Processing Record 14 of Set 11 | grand gaube
# Processing Record 15 of Set 11 | brighton
# Processing Record 16 of Set 11 | kachiry
# Processing Record 17 of Set 11 | thinadhoo
# Processing Record 18 of Set 11 | celestun
# Processing Record 19 of Set 11 | buala
# Processing Record 20 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 21 of Set 11 | merta
# Processing Record 22 of Set 11 | zhangye
# Processing Record 23 of Set 11 | gasa
# Processing Record 24 of Set 11 | baykit
# Processing Record 25 of Set 11 | evans
# Processing Record 26 of Set 11 | dryden
# Processing Record 27 of Set 11 | ballina
# Processing Record 28 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 29 of Set 11 | conde
# Processing Record 30 of Set 11 | sept-iles
# Processing Record 31 of Set 11 | melekhovskaya
# City not found. Skipping...
# Processing Record 32 of Set 11 | himensulan
# Processing Record 33 of Set 11 | bell ville
# Processing Record 34 of Set 11 | auki
# Processing Record 35 of Set 11 | yishui
# Processing Record 36 of Set 11 | houma
# Processing Record 37 of Set 11 | sao pedro
# Processing Record 38 of Set 11 | khash
# Processing Record 39 of Set 11 | norrtalje
# Processing Record 40 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 41 of Set 11 | ostrovnoy
# Processing Record 42 of Set 11 | sao felix do xingu
# Processing Record 43 of Set 11 | ziyang
# Processing Record 44 of Set 11 | puerto colombia
# Processing Record 45 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 46 of Set 11 | kununurra
# Processing Record 47 of Set 11 | northam
# Processing Record 48 of Set 11 | bowen
# Processing Record 49 of Set 11 | sorland
# Processing Record 50 of Set 11 | voyvozh
# Processing Record 1 of Set 12 | limbang
# Processing Record 2 of Set 12 | yongan
# Processing Record 3 of Set 12 | lircay
# Processing Record 4 of Set 12 | valera
# Processing Record 5 of Set 12 | portel
# Processing Record 6 of Set 12 | kutum
# Processing Record 7 of Set 12 | baraboo
# Processing Record 8 of Set 12 | guerrero negro
# Processing Record 9 of Set 12 | nurota
# Processing Record 10 of Set 12 | kudahuvadhoo
# Processing Record 11 of Set 12 | xining
# Processing Record 12 of Set 12 | sawakin
# Processing Record 13 of Set 12 | soure
# Processing Record 14 of Set 12 | batsfjord
# Processing Record 15 of Set 12 | talagang
# Processing Record 16 of Set 12 | lososina
# Processing Record 17 of Set 12 | sao jose da coroa grande
# Processing Record 18 of Set 12 | aquiraz
# Processing Record 19 of Set 12 | huarmey
# Processing Record 20 of Set 12 | te anau
# Processing Record 21 of Set 12 | san pedro de cajas
# Processing Record 22 of Set 12 | tonstad
# Processing Record 23 of Set 12 | meulaboh
# Processing Record 24 of Set 12 | arzgir
# Processing Record 25 of Set 12 | chiguayante
# Processing Record 26 of Set 12 | general roca
# Processing Record 27 of Set 12 | atambua
# Processing Record 28 of Set 12 | hay river
# Processing Record 29 of Set 12 | lieksa
# Processing Record 30 of Set 12 | shenjiamen
# Processing Record 31 of Set 12 | ugleuralskiy
# Processing Record 32 of Set 12 | kirakira
# Processing Record 33 of Set 12 | luganville
# Processing Record 34 of Set 12 | saint anthony
# Processing Record 35 of Set 12 | koyilandi
# City not found. Skipping...
# Processing Record 36 of Set 12 | totma
# Processing Record 37 of Set 12 | sambava
# Processing Record 38 of Set 12 | tambovka
# Processing Record 39 of Set 12 | olafsvik
# Processing Record 40 of Set 12 | belaya kholunitsa
# Processing Record 41 of Set 12 | kachug
# Processing Record 42 of Set 12 | kollumerland
# City not found. Skipping...
# Processing Record 43 of Set 12 | marsh harbour
# Processing Record 44 of Set 12 | laela
# Processing Record 45 of Set 12 | careiro da varzea
# Processing Record 46 of Set 12 | la fleche
# Processing Record 47 of Set 12 | acajutla
# Processing Record 48 of Set 12 | batagay-alyta
# Processing Record 49 of Set 12 | labrea
# Processing Record 50 of Set 12 | lugazi
# Processing Record 1 of Set 13 | manjacaze
# Processing Record 2 of Set 13 | mana
# Processing Record 3 of Set 13 | biggar
# Processing Record 4 of Set 13 | itarare
# Processing Record 5 of Set 13 | victor harbor
# Processing Record 6 of Set 13 | aksha
# Processing Record 7 of Set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 8 of Set 13 | charyshskoye
# Processing Record 9 of Set 13 | pemex
# Processing Record 10 of Set 13 | kiama
# Processing Record 11 of Set 13 | dunedin
# Processing Record 12 of Set 13 | rocha
# Processing Record 13 of Set 13 | los llanos de aridane
# Processing Record 14 of Set 13 | sagua la grande
# Processing Record 15 of Set 13 | aranos
# Processing Record 16 of Set 13 | sivas
# Processing Record 17 of Set 13 | kieta
# Processing Record 18 of Set 13 | sieradz
# Processing Record 19 of Set 13 | maracaibo
# Processing Record 20 of Set 13 | zhigansk
# Processing Record 21 of Set 13 | bandarbeyla
# Processing Record 22 of Set 13 | chippewa falls
# Processing Record 23 of Set 13 | haines junction
# Processing Record 24 of Set 13 | ahuimanu
# Processing Record 25 of Set 13 | sao joao da barra
# Processing Record 26 of Set 13 | sydney
# Processing Record 27 of Set 13 | sitka
# Processing Record 28 of Set 13 | cullen
# Processing Record 29 of Set 13 | filadelfia
# Processing Record 30 of Set 13 | sirsi
# Processing Record 31 of Set 13 | topolobampo
# Processing Record 32 of Set 13 | vila franca do campo
# Processing Record 33 of Set 13 | mendi
# Processing Record 34 of Set 13 | yegros
# Processing Record 35 of Set 13 | kaili
# Processing Record 36 of Set 13 | copiapo
# Processing Record 37 of Set 13 | benghazi
# Processing Record 38 of Set 13 | new glasgow
# Processing Record 39 of Set 13 | noumea
# Processing Record 40 of Set 13 | wawa
# Processing Record 41 of Set 13 | lima
# Processing Record 42 of Set 13 | caninde de sao francisco
# Processing Record 43 of Set 13 | san jose
# Processing Record 44 of Set 13 | waipawa
# Processing Record 45 of Set 13 | teknaf
# Processing Record 46 of Set 13 | salinas
# Processing Record 47 of Set 13 | zyryanka
# Processing Record 48 of Set 13 | tessalit
# Processing Record 49 of Set 13 | saint-louis
# Processing Record 50 of Set 13 | pilani
# Processing Record 1 of Set 14 | peniche
# Processing Record 2 of Set 14 | nakhon phanom
# Processing Record 3 of Set 14 | vila
# Processing Record 4 of Set 14 | semarang
# Processing Record 5 of Set 14 | richards bay
# Processing Record 6 of Set 14 | kitami
# Processing Record 7 of Set 14 | maxixe
# Processing Record 8 of Set 14 | sundumbili
# Processing Record 9 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 10 of Set 14 | hermon
# Processing Record 11 of Set 14 | cefa
# Processing Record 12 of Set 14 | kolar
# Processing Record 13 of Set 14 | edd
# Processing Record 14 of Set 14 | churapcha
# Processing Record 15 of Set 14 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 16 of Set 14 | freetown
# Processing Record 17 of Set 14 | kalamb
# Processing Record 18 of Set 14 | dubuque
# Processing Record 19 of Set 14 | buritis
# Processing Record 20 of Set 14 | kulhudhuffushi
# Processing Record 21 of Set 14 | sulangan
# Processing Record 22 of Set 14 | limoux
# Processing Record 23 of Set 14 | lasa
# Processing Record 24 of Set 14 | paracatu
# Processing Record 25 of Set 14 | terre haute
# Processing Record 26 of Set 14 | santa lucia
# Processing Record 27 of Set 14 | hokitika
# Processing Record 28 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 29 of Set 14 | iquitos
# Processing Record 30 of Set 14 | greenville
# Processing Record 31 of Set 14 | tongzi
# Processing Record 32 of Set 14 | haimen
# Processing Record 33 of Set 14 | alexandria
# Processing Record 34 of Set 14 | satitoa
# City not found. Skipping...
# Processing Record 35 of Set 14 | maha sarakham
# Processing Record 36 of Set 14 | dargaville
# Processing Record 37 of Set 14 | okha
# Processing Record 38 of Set 14 | tamiahua
# Processing Record 39 of Set 14 | kabinda
# Processing Record 40 of Set 14 | port moresby
# Processing Record 41 of Set 14 | tsihombe
# City not found. Skipping...
# Processing Record 42 of Set 14 | mabaruma
# Processing Record 43 of Set 14 | umm kaddadah
# Processing Record 44 of Set 14 | aflu
# City not found. Skipping...
# Processing Record 45 of Set 14 | bilibino
# Processing Record 46 of Set 14 | sohag
# Processing Record 47 of Set 14 | nemuro
# Processing Record 48 of Set 14 | saleaula
# City not found. Skipping...
# Processing Record 49 of Set 14 | nyrob
# Processing Record 50 of Set 14 | tungkang
# City not found. Skipping...
# Processing Record 1 of Set 15 | mitu
# Processing Record 2 of Set 15 | diu
# Processing Record 3 of Set 15 | tuggurt
# City not found. Skipping...
# Processing Record 4 of Set 15 | tete
# Processing Record 5 of Set 15 | kenai
# Processing Record 6 of Set 15 | nioro
# Processing Record 7 of Set 15 | baie-comeau
# Processing Record 8 of Set 15 | riberalta
# Processing Record 9 of Set 15 | shelopugino
# Processing Record 10 of Set 15 | mahajanga
# Processing Record 11 of Set 15 | buon me thuot
# City not found. Skipping...
# Processing Record 12 of Set 15 | rorvik
# Processing Record 13 of Set 15 | villarrubia de los ojos
# Processing Record 14 of Set 15 | swan hill
# Processing Record 15 of Set 15 | koindu
# Processing Record 16 of Set 15 | ngunguru
# Processing Record 17 of Set 15 | cardinal
# Processing Record 18 of Set 15 | semey
# Processing Record 19 of Set 15 | assiniboia
# Processing Record 20 of Set 15 | esso
# Processing Record 21 of Set 15 | buenos aires
# Processing Record 22 of Set 15 | mamit
# Processing Record 23 of Set 15 | ossora
# Processing Record 24 of Set 15 | jizan
# Processing Record 25 of Set 15 | kamaishi
# Processing Record 26 of Set 15 | bon air
# Processing Record 27 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 28 of Set 15 | oistins
# Processing Record 29 of Set 15 | nueva loja
# Processing Record 30 of Set 15 | safaga
# Processing Record 31 of Set 15 | zhanatas
# City not found. Skipping...
# Processing Record 32 of Set 15 | benemerito de las americas
# Processing Record 33 of Set 15 | angoche
# Processing Record 34 of Set 15 | aykhal
# Processing Record 35 of Set 15 | ulaangom
# Processing Record 36 of Set 15 | port-de-bouc
# Processing Record 37 of Set 15 | methoni
# Processing Record 38 of Set 15 | palu
# Processing Record 39 of Set 15 | winthrop
# Processing Record 40 of Set 15 | ust-kulom
# Processing Record 41 of Set 15 | concepcion del oro
# Processing Record 42 of Set 15 | lata
# Processing Record 43 of Set 15 | el retorno
# Processing Record 44 of Set 15 | sale
# Processing Record 45 of Set 15 | olesno
# Processing Record 46 of Set 15 | sabang
# Processing Record 47 of Set 15 | dombarovskiy
# Processing Record 48 of Set 15 | maningrida
# Processing Record 49 of Set 15 | sokoni
# Processing Record 50 of Set 15 | tautira
# Processing Record 1 of Set 16 | gizo
# Processing Record 2 of Set 16 | kemijarvi
# Processing Record 3 of Set 16 | brae
# Processing Record 4 of Set 16 | umzimvubu
# City not found. Skipping...
# Processing Record 5 of Set 16 | champerico
# Processing Record 6 of Set 16 | prado
# Processing Record 7 of Set 16 | zhuzhou
# Processing Record 8 of Set 16 | half moon bay
# Processing Record 9 of Set 16 | kichmengskiy gorodok
# Processing Record 10 of Set 16 | catuday
# Processing Record 11 of Set 16 | gondar
# Processing Record 12 of Set 16 | pailon
# Processing Record 13 of Set 16 | duz
# City not found. Skipping...
# Processing Record 14 of Set 16 | wajid
# Processing Record 15 of Set 16 | kathmandu
# Processing Record 16 of Set 16 | kotelnich
# Processing Record 17 of Set 16 | qaqortoq
# Processing Record 18 of Set 16 | laguna
# Processing Record 19 of Set 16 | masterton
# Processing Record 20 of Set 16 | ereymentau
# Processing Record 21 of Set 16 | kotar
# Processing Record 22 of Set 16 | dibulla
# Processing Record 23 of Set 16 | mestia
# Processing Record 24 of Set 16 | babanusah
# City not found. Skipping...
# Processing Record 25 of Set 16 | husavik
# Processing Record 26 of Set 16 | belmonte
# Processing Record 27 of Set 16 | mojo
# Processing Record 28 of Set 16 | griffith
# Processing Record 29 of Set 16 | trabzon
# Processing Record 30 of Set 16 | arlit
# Processing Record 31 of Set 16 | sioux lookout
# Processing Record 32 of Set 16 | toftir
# City not found. Skipping...
# Processing Record 33 of Set 16 | sire
# Processing Record 34 of Set 16 | kawalu
# Processing Record 35 of Set 16 | sarangani
# Processing Record 36 of Set 16 | diamantino
# Processing Record 37 of Set 16 | khani
# Processing Record 38 of Set 16 | grand-lahou
# Processing Record 39 of Set 16 | morgan city
# Processing Record 40 of Set 16 | fort frances
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 729

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0             Roald  62.5833    6.1333     60.75        94         100
# 1            Torbay  47.6666  -52.7314     43.75        89          75
# 2         Ilulissat  69.2167  -51.1000     21.22        73          75
# 3             Bluff -46.6000  168.3333     54.61        78         100
# 4  Candido De Abreu -24.5669  -51.3333     67.59        82         100
# 5     Mar Del Plata -38.0023  -57.5575     71.83        87           0
# 6            Atuona  -9.8000 -139.0333     77.22        81          12
# 7             Vaini -21.2000 -175.2000     78.96        94          40
# 8      Presque Isle  46.6811  -68.0159     60.30        59          40
# 9          Bengkulu  -3.8004  102.2655     74.48        92          94
#
#    Wind Speed Country Current Description
# 0       24.16      NO       moderate rain
# 1       11.50      CA          light rain
# 2        6.91      GL       broken clouds
# 3        4.12      NZ     overcast clouds
# 4        2.39      BR     overcast clouds
# 5       12.66      AR           clear sky
# 6       15.10      PF          few clouds
# 7        6.91      TO    scattered clouds
# 8        4.61      US    scattered clouds
# 9        3.65      ID     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0             Roald      NO  62.5833    6.1333     60.75        94
# 1            Torbay      CA  47.6666  -52.7314     43.75        89
# 2         Ilulissat      GL  69.2167  -51.1000     21.22        73
# 3             Bluff      NZ -46.6000  168.3333     54.61        78
# 4  Candido De Abreu      BR -24.5669  -51.3333     67.59        82
# 5     Mar Del Plata      AR -38.0023  -57.5575     71.83        87
# 6            Atuona      PF  -9.8000 -139.0333     77.22        81
# 7             Vaini      TO -21.2000 -175.2000     78.96        94
# 8      Presque Isle      US  46.6811  -68.0159     60.30        59
# 9          Bengkulu      ID  -3.8004  102.2655     74.48        92
#
#    Cloudiness  Wind Speed Current Description
# 0         100       24.16       moderate rain
# 1          75       11.50          light rain
# 2          75        6.91       broken clouds
# 3         100        4.12     overcast clouds
# 4         100        2.39     overcast clouds
# 5           0       12.66           clear sky
# 6          12       15.10          few clouds
# 7          40        6.91    scattered clouds
# 8          40        4.61    scattered clouds
# 9          94        3.65     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
